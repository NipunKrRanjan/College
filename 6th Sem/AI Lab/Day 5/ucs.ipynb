# %%
print("Name :Nipun Kumar Ranjan")
print("Roll no : 23052738")
import heapq

def uniform_cost_search(graph, start, goal):
    pq = []
    heapq.heappush(pq, (0, start, [start]))
    visited = {}

    while pq:
        cost, node, path = heapq.heappop(pq)

        if node == goal:
            return cost, path

        if node in visited and visited[node] <= cost:
            continue

        visited[node] = cost

        for neighbor, weight in graph[node]:
            heapq.heappush(
                pq,
                (cost + weight, neighbor, path + [neighbor])
            )

    return float("inf"), []

graph = {
    "A": [("B", 1), ("C", 4)],
    "B": [("C", 2), ("D", 5)],
    "C": [("D", 1)],
    "D": []
}

start = "A"
goal = "D"

cost, path = uniform_cost_search(graph, start, goal)

print("Path:", path)
print("Total Cost:", cost)
# Out:
# Nipun Kumar Ranjan
# 23052738
# CSE-20
# Enter edges as 'Start End Cost' (e.g., A B 5). Type 'go' to run.
# ---------------------------------------------------------------------------
# IndexError                                Traceback (most recent call last)
# Cell In[2], line 26
#      24 while True:
#      25     entry = input("> ").split()
# ---> 26     if entry[0].lower() == 'go': break
#      28     u, v, w = entry
#      29     if u not in graph: graph[u] = []
#
# IndexError: list index out of range
