# %%
#use of if-elif-else statement
marks=int(input("Enter marks"))
print("Nipun Kumar Ranjan\n23052738\nMarks Enter",marks)
print("Grade Recieved")
if(marks>=90):
    print("Grade A")
elif(marks<90 and marks>=80):
    print("Grade B")
elif(marks<80 and marks>=70):
    print("Grade C")
else:
    print("Grade D")
# Out:
# Nipun Kumar Ranjan
# 23052738
# Marks Enter 40
# Grade Recieved
# Grade D

# %%
#use of for loop
num=[1,2,3,4,5]
for i in num:
    print(i)
# Out:
# 1
# 2
# 3
# 4
# 5
